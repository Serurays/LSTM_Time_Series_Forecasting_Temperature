# %% [markdown]
# <a href="https://colab.research.google.com/github/Serurays/LSTM_Time_Series_Forecasting_Temperature/blob/main/LSTM_Time_Series_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)
# Out:
# ...
# 13568290/13568290 [==============================] - 0s 0us/step

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df = df[5::6]
df.head()
# Out:
#               Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 5   01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 11  01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 17  01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 23  01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 29  01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#     VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 5           3.33          3.14          0.19       1.96             3.15
# 11          3.12          2.90          0.21       1.81             2.91
# 17          3.13          2.93          0.20       1.83             2.94
# 23          3.07          2.85          0.23       1.78             2.85
# 29          2.94          2.71          0.23       1.69             2.71
#
#     rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# ...

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')

# %%
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33     -9.17    264.12
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17     -8.10    265.12
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69     -7.66    265.52
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27     -7.04    266.10
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87     -7.41    265.68
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# ...

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <Axes: xlabel='Date Time'>

# %%
def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+5]]
    X.append(row)
    label = df_as_np[i+5]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X, y = df_to_X_y(temp, WINDOW_SIZE)

# %%
X.shape, y.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X_train, y_train = X[:60000], y[:60000]
X_val, y_val = X[60000:65000], y[60000:65000]
X_test, y_test = X[65000:], y[65000:]

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((60000, 5, 1), (5000, 5, 1), (5086, 5, 1))

# %%
y_train.shape, y_val.shape, y_test.shape
# Out:
# ((60000,), (5000,), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# ...
# Total params: 17425 (68.07 KB)
# Trainable params: 17425 (68.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cp = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 13s 6ms/step - loss: 34.4104 - root_mean_squared_error: 5.8660 - val_loss: 1.2572 - val_root_mean_squared_error: 1.1213
# Epoch 2/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 2.1434 - root_mean_squared_error: 1.4640 - val_loss: 0.6234 - val_root_mean_squared_error: 0.7896
# Epoch 3/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.9409 - root_mean_squared_error: 0.9700 - val_loss: 0.5365 - val_root_mean_squared_error: 0.7324
# Epoch 4/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.7378 - root_mean_squared_error: 0.8590 - val_loss: 0.5124 - val_root_mean_squared_error: 0.7158
# Epoch 5/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.6861 - root_mean_squared_error: 0.8283 - val_loss: 0.5003 - val_root_mean_squared_error: 0.7073
# Epoch 6/10
# ...

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/')

# %%
train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train})
train_results
# Out:
# 1875/1875 [==============================] - 5s 2ms/step
#        Train Predictions  Actuals
# 0              -9.858887    -9.67
# 1              -9.679831    -9.17
# 2              -8.868075    -8.10
# 3              -7.370432    -7.66
# 4              -7.255310    -7.04
# ...                  ...      ...
# 59995           6.002847     6.07
# 59996           7.322164     9.88
# 59997          12.350504    13.53
# 59998          15.959058    15.43
# 59999          16.223280    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
val_predictions = model1.predict(X_val).flatten()
val_results = pd.DataFrame(data={'Validation Predictions':val_predictions, 'Actuals':y_val})
val_results
# Out:
# 157/157 [==============================] - 1s 3ms/step
#       Validation Predictions  Actuals
# 0                  15.486511    14.02
# 1                  13.341331    13.67
# 2                  13.023872    12.27
# 3                  11.525778    11.19
# 4                  10.412811    10.85
# ...                      ...      ...
# 4995               17.352095    18.27
# 4996               17.311014    17.85
# 4997               17.127726    16.65
# 4998               15.865995    15.85
# 4999               15.050172    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Validation Predictions'][50:100])
plt.plot(val_results['Actuals'][50:100])

# %%
test_predictions = model1.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test})
test_results
# Out:
# 159/159 [==============================] - 0s 2ms/step
#       Test Predictions  Actuals
# 0            14.371604    13.99
# 1            13.254622    13.46
# 2            12.835002    12.93
# 3            12.434650    12.43
# 4            12.000568    12.17
# ...                ...      ...
# 5081         -1.129752    -0.98
# 5082         -1.410753    -1.40
# 5083         -1.667288    -2.75
# 5084         -3.174659    -2.89
# 5085         -3.074623    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][50:100])
plt.plot(test_results['Actuals'][50:100])
